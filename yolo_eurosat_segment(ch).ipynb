# %% [markdown]
# <a href="https://colab.research.google.com/github/Uday-ashes-uday/deep-learning/blob/main/yolo_eurosat_segment(ch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.28

# %%
from IPython import display
display.clear_output()

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.5/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt conf=0.25 source='https://media-cldnry.s-nbcnews.com/image/upload/t_fit-1240w,f_auto,q_auto:eco,dpr_2.0/rockcms/2022-03/black-lab-favorite-dog-main-220315-e8e0ee.jpg' save=True
# Out:
# 2023-08-10 16:02:15.291025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# Found https://media-cldnry.s-nbcnews.com/image/upload/t_fit-1240w,f_auto,q_auto:eco,dpr_2.0/rockcms/2022-03/black-lab-favorite-dog-main-220315-e8e0ee.jpg locally at black-lab-favorite-dog-main-220315-e8e0ee.jpg
# image 1/1 /content/drive/MyDrive/experiment segmentation/black-lab-favorite-dog-main-220315-e8e0ee.jpg: 448x640 1 dog, 360.1ms
# Speed: 0.8ms pre-process, 360.1ms inference, 356.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict3

# %%
# %cd '/content/drive/MyDrive/experiment segmentation'
# Out:
# /content/drive/MyDrive/experiment segmentation

# %%
# !pwd
# Out:
# /content/drive/MyDrive/experiment segmentation

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=data.yaml epochs=10 imgsz=32 save=True
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image('/content/drive/MyDrive/experiment segmentation/runs/segment/train2/results.png')

# %%
Image('/content/drive/MyDrive/experiment segmentation/runs/segment/train2/train_batch0.jpg')

# %%
# !yolo task=segment mode=predict model='/content/drive/MyDrive/experiment segmentation/runs/segment/train3/weights/best.pt' conf=0.75 source='/content/drive/MyDrive/experiment segmentation/S2A_MSIL1C_20230608T052651_N0509_R105_T43RGL_20230608T072546_RGB.png' save=true
# Out:
# 2023-08-10 16:14:34.111131: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/experiment segmentation/S2A_MSIL1C_20230608T052651_N0509_R105_T43RGL_20230608T072546_RGB.png: 448x640 300 rivers, 82.2ms
# Speed: 0.6ms pre-process, 82.2ms inference, 137.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict8
